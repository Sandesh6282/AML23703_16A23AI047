# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

qc = QuantumCircuit(1)

qc.h(0)

state = Statevector.from_instruction(qc)

probabilities = state.probabilities()

print(qc)

print("\nProbability of Heads:", probabilities[0])
print("Probability of Tails:", probabilities[1])
# Out:
#    ┌───┐
# q: ┤ H ├
#    └───┘
#
# Probability of Heads: 0.4999999999999999
# Probability of Tails: 0.4999999999999999
