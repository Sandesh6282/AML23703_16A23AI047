# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# HZH Circuit
circuit1 = QuantumCircuit(1)
circuit1.h(0)
circuit1.z(0)
circuit1.h(0)

# X Gate Circuit
circuit2 = QuantumCircuit(1)
circuit2.x(0)

state1 = Statevector.from_instruction(circuit1)
state2 = Statevector.from_instruction(circuit2)

print("HZH Circuit")
print(circuit1)

print("\nX Gate Circuit")
print(circuit2)

print("\nHZH Statevector")
print(state1)

print("\nX Gate Statevector")
print(state2)

print("\nEquivalent:", state1.equiv(state2))
# Out:
# HZH Circuit
#    ┌───┐┌───┐┌───┐
# q: ┤ H ├┤ Z ├┤ H ├
#    └───┘└───┘└───┘
#
# X Gate Circuit
#    ┌───┐
# q: ┤ X ├
#    └───┘
#
# HZH Statevector
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
#
# X Gate Statevector
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
#
# Equivalent: True
